# %% [markdown]
# <a href="https://colab.research.google.com/github/77notgnillew/Estudos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string = "ABCDE"

lista = []

print(lista, type(lista))
# Out:
# [] <class 'list'>

# %%
lista = [123, "nome", 1.6, False, []]
print(lista)
print(len(lista))
# Out:
# [123, 'nome', 1.6, False, []]
# 5

# %%
lista = [1, 2, 3, 4]
print(lista)
lista.insert(2, 50)
print(lista)
# Out:
# [1, 2, 3, 4]
# [1, 2, 50, 3, 4]

# %%
lista_a = [1, 2, 3, 4]
lista_b = [4, 5, 6, 7]
lista_c = lista_b + lista_a

print(lista_c)

lista_a.extend(lista_b)

print(lista_a)
print(lista_b)
# Out:
# [4, 5, 6, 7, 1, 2, 3, 4]
# [1, 2, 3, 4, 4, 5, 6, 7]
# [4, 5, 6, 7]

# %%
lista_a = ["luiz", "maria"]
lista_b = lista_a.copy()

lista_a[0] = "qualquer"
print(lista_b)
print(lista_a)
# Out:
# ['luiz', 'maria']
# ['qualquer', 'maria']

# %%
lista = ["maria", "helena", "luiz"]

for nome in lista:
  print(nome)
# Out:
# maria
# helena
# luiz
